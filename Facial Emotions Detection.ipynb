# %%
pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\hi\anaconda3\lib\site-packages (0.0.79)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (0.0.13)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (2.13.0)
# Requirement already satisfied: fire>=0.4.0 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (0.5.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (21.2.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (1.24.3)
# Requirement already satisfied: keras>=2.2.0 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (2.13.1)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (9.2.0)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (1.4.4)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (4.64.1)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (4.8.0.74)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\hi\anaconda3\lib\site-packages (from deepface) (4.7.1)
# Requirement already satisfied: termcolor in c:\users\hi\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (2.3.0)
# Requirement already satisfied: six in c:\users\hi\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\hi\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\hi\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\hi\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\hi\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: requests[socks] in c:\users\hi\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (2.28.1)
# Requirement already satisfied: filelock in c:\users\hi\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\hi\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Requirement already satisfied: packaging in c:\users\hi\anaconda3\lib\site-packages (from gunicorn>=20.1.0->deepface) (21.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hi\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hi\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2022.1)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: setuptools in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (63.4.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (4.23.4)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (16.0.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.56.2)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\hi\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (4.3.0)
# Requirement already satisfied: colorama in c:\users\hi\anaconda3\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hi\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hi\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hi\anaconda3\lib\site-packages (from packaging->gunicorn>=20.1.0->deepface) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hi\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hi\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hi\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hi\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.9.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\hi\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\hi\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hi\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.22.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hi\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.7.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hi\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hi\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#import the required modules
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
# read image
img = cv2.imread('img.jpeg')

# call imshow() using plt object
plt.imshow(img[:, :, : : -1])

# display that image
plt.show()

# %%
# storing the result
result = DeepFace.analyze(img,actions = ['emotion'])
# print result
print(result)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\HI\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████████████████████████████████████████████████████████████████████████| 5.98M/5.98M [00:12<00:00, 487kB/s]
# Action: emotion: 100%|███████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.12it/s]
# [{'emotion': {'angry': 0.0358239790289377, 'disgust': 0.02429289596340683, 'fear': 25.19557180351875, 'happy': 74.24929431072405, 'sad': 0.2568912765775653, 'surprise': 0.22966899387317824, 'neutral': 0.008459123918104787}, 'dominant_emotion': 'happy', 'region': {'x': 97, 'y': 37, 'w': 96, 'h': 96}}]

# %%
# import the required modules
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# read image
img = cv2.imread('img.jpeg')

# call imshow() using plt object
plt.imshow(img[:,:,::-1])

# display that image
plt.show()

# storing the result
result = DeepFace.analyze(img,actions=['emotion'])

# print result
print(result)
# Out:
# Action: emotion: 100%|███████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.01it/s]
# [{'emotion': {'angry': 0.0358239790289377, 'disgust': 0.02429289596340683, 'fear': 25.19557180351875, 'happy': 74.24929431072405, 'sad': 0.2568912765775653, 'surprise': 0.22966899387317824, 'neutral': 0.008459123918104787}, 'dominant_emotion': 'happy', 'region': {'x': 97, 'y': 37, 'w': 96, 'h': 96}}]
